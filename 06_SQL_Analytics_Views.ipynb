-- %%
CREATE OR REPLACE VIEW workspace.default.vw_top_product_categories AS
SELECT *
FROM workspace.default.gold_product_performance
ORDER BY total_revenue DESC;

-- %%
CREATE OR REPLACE VIEW workspace.default.vw_top_vendors AS
SELECT *
FROM workspace.default.gold_vendor_performance
ORDER BY vendor_revenue DESC;

-- %%
CREATE OR REPLACE VIEW workspace.default.vw_country_sales AS
SELECT *
FROM workspace.default.gold_country_sales
ORDER BY country_revenue DESC;

-- %%
CREATE OR REPLACE VIEW workspace.default.vw_rebuy_analysis AS
SELECT *
FROM workspace.default.gold_rebuy;

-- %%
SELECT * FROM workspace.default.vw_top_product_categories;
